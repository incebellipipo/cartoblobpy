# %%
from cartoblobpy.map_generation import create_map

# Istanbul
# lat_tl, lon_tl = 41.046893, 28.927251
# lat_br, lon_br = 40.962086, 29.101507

# Trondheim
lat_tl, lon_tl = 63.464855, 10.321716
lat_br, lon_br = 63.423063, 10.447594

# Trondhiem large
# lat_tl, lon_tl = 63.669637, 9.233248
# lat_br, lon_br = 63.279091, 10.987246

# Oslo
# lat_tl, lon_tl = 59.92, 10.65
# lat_br, lon_br = 59.88, 10.75



create_map(
    lat_tl=lat_tl,
    lon_tl=lon_tl,
    lat_br=lat_br,
    lon_br=lon_br,
    resolution=2.0,
    water_color="#ffffff",
    land_color="#000000",
    transparent_water=True,
)
# Out:
# Map saved to map.png (3189x2260 px)
# Metadata saved to map.yaml
